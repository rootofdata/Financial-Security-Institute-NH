# %%
import pandas as pd
import numpy as np
import os

# %%
path = 'C:/Users/user/Desktop/경진대회/KRX 데이터/전종목 등락률/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]
file_list_py

df = pd.DataFrame()
Timeindex = pd.date_range('9/1/2018', periods= len(file_list_py), freq = 'M')
for i, time in zip(file_list_py,Timeindex):
    data = pd.read_csv(path + i, encoding= 'cp949')
    data_df = pd.DataFrame(data)
    data_df['기준년월'] = time
    df = pd.concat([df, data])
 
df_UD = df.reset_index(drop=True)

# %%
df_UD
# Out:
#          종목코드      종목명  시작일 기준가  종료일 종가     대비    등락률       거래량          거래대금  \
# 0       60310       3S     2675    2060   -615 -22.99   3542373  8.065309e+09
# 1       95570   AJ네트웍스     6160    4555  -1605 -26.06   1216041  6.231516e+09
# 2       68400    AJ렌터카    13500   10700  -2800 -20.74   7752325  9.810552e+10
# 3        6840    AK홀딩스    61200   44600 -16600 -27.12    788157  3.947046e+10
# 4       54620   APS홀딩스     5360    4020  -1340 -25.00   1262482  5.570378e+09
# ...       ...      ...      ...     ...    ...    ...       ...           ...
# 83223     547  흥국화재2우B    30650   31700   1050   3.43    170573  5.709731e+09
# 83224     545    흥국화재우    10900   11300    400   3.67    410258  4.818654e+09
# 83225    3280     흥아해운      258     258      0   0.00         0  0.000000e+00
# 83226   37440       희림     8430    8170   -260  -3.08  42158093  4.123740e+11
# 83227  238490       힘스    11550   11750    200   1.73   1550006  1.803213e+10
#
#             기준년월
# 0     2018-09-30
# 1     2018-09-30
# 2     2018-09-30
# 3     2018-09-30
# 4     2018-09-30
# ...          ...
# 83223 2021-06-30
# 83224 2021-06-30
# 83225 2021-06-30
# 83226 2021-06-30
# 83227 2021-06-30
#
# [83228 rows x 9 columns]

# %%
import pandas as pd

# %%
path = 'C:/Users/user/Desktop/경진대회/KRX 데이터/투자자별 순매수 (기관합계)/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-8274c6e591b7> in <module>
#       1 path = 'C:/Users/user/Desktop/경진대회/KRX 데이터/투자자별 순매수 (기관합계)/'
# ----> 2 file_list = os.listdir(path)
#       3 file_list_py = [file for file in file_list if file.endswith('.csv')]
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: 'C:/Users/user/Desktop/경진대회/KRX 데이터/투자자별 순매수 (기관합계)/'

# %%
Timeindex = pd.date_range('9/1/2018', periods= len(file_list_py), freq = 'M')
Timeindex
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-32af70e19ad1> in <module>
# ----> 1 Timeindex = pd.date_range('9/1/2018', periods= len(file_list_py), freq = 'M')
#       2 Timeindex
#
# NameError: name 'file_list_py' is not defined

# %%
path = 'C:/Users/user/Desktop/경진대회/KRX 데이터/투자자별 순매수 (기관합계)/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]

df = pd.DataFrame()
Timeindex = pd.date_range('9/1/2018', periods= len(file_list_py), freq = 'M')
for i, time in zip(file_list_py,Timeindex):
    data = pd.read_csv(path + i, encoding= 'cp949')
    data_df = pd.DataFrame(data)
    data_df['기준년월'] = time
    df = pd.concat([df, data])
    
df_CO = df.reset_index(drop=True)

# %%
df_CO
# Out:
#          종목코드      종목명     거래량_매도     거래량_매수   거래량_순매수       거래대금_매도  \
# 0        5930     삼성전자   76293686   91980349  15686663  3.318310e+12
# 1       68270     셀트리온    4116465    6167631   2051166  1.044150e+12
# 2        9150     삼성전기    5402830    8959666   3556836  6.827450e+11
# 3       96770  SK이노베이션    1748157    2567603    819446  3.746560e+11
# 4       51910     LG화학    1678730    2126218    447488  5.555440e+11
# ...       ...      ...        ...        ...       ...           ...
# 77294   11170    롯데케미칼    1714614     592693  -1121921  4.645030e+11
# 77295   51910     LG화학    1570873    1188321   -382552  1.289180e+12
# 77296   35720      카카오   42143561   39971905  -2171656  6.324990e+12
# 77297  352820      하이브    4003584    2707346  -1296238  1.165500e+12
# 77298    5930     삼성전자  156738703  143778289 -12960414  1.272950e+13
#
#             거래대금_매수      거래대금_순매수       기준년월
# 0      3.970670e+12  6.523510e+11 2018-09-30
# 1      1.534400e+12  4.902510e+11 2018-09-30
# 2      1.135390e+12  4.526450e+11 2018-09-30
# 3      5.505560e+11  1.759000e+11 2018-09-30
# 4      7.028000e+11  1.472570e+11 2018-09-30
# ...             ...           ...        ...
# 77294  1.614640e+11 -3.030390e+11 2021-06-30
# 77295  9.803700e+11 -3.088110e+11 2021-06-30
# 77296  5.975250e+12 -3.497430e+11 2021-06-30
# 77297  7.811040e+11 -3.843990e+11 2021-06-30
# 77298  1.168820e+13 -1.041300e+12 2021-06-30
#
# [77299 rows x 9 columns]

# %%
path = 'C:/Users/user/Desktop/경진대회/KRX 데이터/투자자별 순매수(개인)/'
fi(path + i, encoding= 'cp949')
    data_df = pd.DataFle_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]

df = pd.DataFrame()
Timeindex = pd.date_range('9/1/2018', periods= len(file_list_py), freq = 'M')
for i, time in zip(file_list_py,Timeindex):
    data = pd.read_csvrame(data)
    data_df['기준년월'] = time
    df = pd.concat([df, data])
 
df_INDI = df.reset_index(drop=True)

# %%
df_INDI
# Out:
#          종목코드         종목명    거래량_매도    거래량_매수  거래량_순매수       거래대금_매도  \
# 0         660      SK하이닉스  15017755  22505473  7487718  1.156730e+12
# 1        9150        삼성전기   6069826   8785205  2715379  9.149020e+11
# 2        5490       POSCO    980886   2064885  1083999  2.948960e+11
# 3        5930        삼성전자  40820189  46400731  5580542  1.884050e+12
# 4       66570        LG전자   7153615  10207716  3054101  5.160460e+11
# ...       ...         ...       ...       ...      ...           ...
# 81103  361610  SK아이이테크놀로지  10965273   8920070 -2045203  1.748440e+12
# 81104     270          기아  33405876  29597122 -3808754  2.983620e+12
# 81105   96770     SK이노베이션  10157913   8621172 -1536741  2.877300e+12
# 81106   35420       NAVER   9900546   8752749 -1147797  3.939600e+12
# 81107    6400       삼성SDI   2850200   2025650  -824550  1.871910e+12
#
#             거래대금_매수      거래대금_순매수       기준년월
# 0      1.718070e+12  5.613480e+11 2018-09-30
# 1      1.303830e+12  3.889230e+11 2018-09-30
# 2      6.234640e+11  3.285690e+11 2018-09-30
# 3      2.119400e+12  2.353470e+11 2018-09-30
# 4      7.333730e+11  2.173270e+11 2018-09-30
# ...             ...           ...        ...
# 81103  1.412470e+12 -3.359760e+11 2021-06-30
# 81104  2.640290e+12 -3.433350e+11 2021-06-30
# 81105  2.426180e+12 -4.511190e+11 2021-06-30
# 81106  3.485760e+12 -4.538410e+11 2021-06-30
# 81107  1.315380e+12 -5.565280e+11 2021-06-30
#
# [81108 rows x 9 columns]

# %%
path = 'C:/Users/user/Desktop/경진대회/KRX 데이터/투자자별 순매수(외국인)/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]

df = pd.DataFrame()
Timeindex = pd.date_range('9/1/2018', periods= len(file_list_py), freq = 'M')
for i, time in zip(file_list_py,Timeindex):
    data = pd.read_csv(path + i, encoding= 'cp949')
    data_df = pd.DataFrame(data)
    data_df['기준년월'] = time
    df = pd.concat([df, data])
 
df_FOR = df.reset_index(drop=True)

# %%
df_FOR

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame(index = Timeindex)
df.index.names = ['기준년월']
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [2018-09-30 00:00:00, 2018-10-31 00:00:00, 2018-11-30 00:00:00, 2018-12-31 00:00:00, 2019-01-31 00:00:00, 2019-02-28 00:00:00, 2019-03-31 00:00:00, 2019-04-30 00:00:00, 2019-05-31 00:00:00, 2019-06-30 00:00:00, 2019-07-31 00:00:00, 2019-08-31 00:00:00, 2019-09-30 00:00:00, 2019-10-31 00:00:00, 2019-11-30 00:00:00, 2019-12-31 00:00:00, 2020-01-31 00:00:00, 2020-02-29 00:00:00, 2020-03-31 00:00:00, 2020-04-30 00:00:00, 2020-05-31 00:00:00, 2020-06-30 00:00:00, 2020-07-31 00:00:00, 2020-08-31 00:00:00, 2020-09-30 00:00:00, 2020-10-31 00:00:00, 2020-11-30 00:00:00, 2020-12-31 00:00:00, 2021-01-31 00:00:00, 2021-02-28 00:00:00, 2021-03-31 00:00:00, 2021-04-30 00:00:00, 2021-05-31 00:00:00, 2021-06-30 00:00:00]

# %%
#관련 종목 추출 함수

def get_category(category, df):
    category_df = df[df['종목명'] == category]
    category_df = category_df[['종목명','시작일 기준가', '종료일 종가', '기준년월']]
    category_df.set_index('기준년월', inplace = True)
    return category_df

def get_plot_2(df, i, y):
    df_end = df[y]
    fig, ax = plt.subplots(1, 1, figsize = (8, 6))
    plt.plot(df_end, 'ko--')
    fig.autofmt_xdate(rotation = 45)
    ax.set_title(str(df['종목명'].unique()))
    plt.show()

# %%
Jeju = get_category('제주맥주', df_UD)
pd.merge(df, Jeju, on = '기준년월', how = 'left')
# Out:
#              종목명  시작일 기준가  종료일 종가
# 기준년월
# 2018-09-30   NaN      NaN     NaN
# 2018-10-31   NaN      NaN     NaN
# 2018-11-30   NaN      NaN     NaN
# 2018-12-31   NaN      NaN     NaN
# 2019-01-31   NaN      NaN     NaN
# 2019-02-28   NaN      NaN     NaN
# 2019-03-31   NaN      NaN     NaN
# 2019-04-30   NaN      NaN     NaN
# 2019-05-31   NaN      NaN     NaN
# 2019-06-30   NaN      NaN     NaN
# 2019-07-31   NaN      NaN     NaN
# 2019-08-31   NaN      NaN     NaN
# 2019-09-30   NaN      NaN     NaN
# 2019-10-31   NaN      NaN     NaN
# 2019-11-30   NaN      NaN     NaN
# 2019-12-31   NaN      NaN     NaN
# 2020-01-31   NaN      NaN     NaN
# 2020-02-29   NaN      NaN     NaN
# 2020-03-31   NaN      NaN     NaN
# 2020-04-30   NaN      NaN     NaN
# 2020-05-31   NaN      NaN     NaN
# 2020-06-30   NaN      NaN     NaN
# 2020-07-31   NaN      NaN     NaN
# 2020-08-31   NaN      NaN     NaN
# 2020-09-30   NaN      NaN     NaN
# 2020-10-31   NaN      NaN     NaN
# 2020-11-30   NaN      NaN     NaN
# 2020-12-31   NaN      NaN     NaN
# 2021-01-31   NaN      NaN     NaN
# 2021-02-28   NaN      NaN     NaN
# 2021-03-31   NaN      NaN     NaN
# 2021-04-30   NaN      NaN     NaN
# 2021-05-31   NaN      NaN     NaN
# 2021-06-30  제주맥주   4840.0  4195.0

# %%
#맷플롯립 한글 설정
import matplotlib.font_manager as fm
font_path = r'C:\Users\user\Desktop\경진대회\NanumFontSetup_TTF_ALL'
fontprop = fm.FontProperties(fname=font_path, size=18)

# %%
import pandas as pd
#matplotlib 패키지 한글 깨짐 처리 시작
import matplotlib.pyplot as plt
import platform
if platform.system() == 'Darwin': #맥
        plt.rc('font', family='AppleGothic') 
elif platform.system() == 'Windows': #윈도우
        plt.rc('font', family='Malgun Gothic') 
elif platform.system() == 'Linux': #리눅스 (구글 콜랩)
        #!wget "https://www.wfonts.com/download/data/2016/06/13/malgun-gothic/malgun.ttf"
        #!mv malgun.ttf /usr/share/fonts/truetype/
        #import matplotlib.font_manager as fm 
        #fm._rebuild() 
        plt.rc('font', family='Malgun Gothic') 
plt.rcParams['axes.unicode_minus'] = False #한글 폰트 사용시 마이너스 폰트 깨짐 해결
#matplotlib 패키지 한글 깨짐 처리 끝

# %%
xlsx = pd.ExcelFile('C:/Users/seven/OneDrive/바탕 화면/경진대회/관련종목.xlsx')
inv_category_S = pd.read_excel(xlsx, sheet_name = '여가-스포츠')
category_list_S = inv_category_S['종목명'].tolist()

# %%
xlsx = pd.ExcelFile('C:/Users/seven/OneDrive/바탕 화면/경진대회/관련종목.xlsx')
inv_category_E = pd.read_excel(xlsx, sheet_name = 'e상품-서비스')
category_list_E = inv_category_E['종목명'].tolist()

# %%
xlsx = pd.ExcelFile('C:/Users/seven/OneDrive/바탕 화면/경진대회/관련종목.xlsx')
inv_category_F = pd.read_excel(xlsx, sheet_name = '식품')
category_list_F = inv_category_F['종목명'].tolist()

# %%
xlsx = pd.ExcelFile('C:/Users/seven/OneDrive/바탕 화면/경진대회/관련종목.xlsx')
inv_category_J = pd.read_excel(xlsx, sheet_name = '식품')
category_list_J = inv_category_J['종목명'].tolist()

# %%
category_S_df_list = []
for i in range(len(category_list_S)):
    category_S_df_list.append(get_category(category_list_S[i], df_UD))
# Out:
# <ipython-input-16-49807ffc4640>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   category_df.sort_values(by = '기준년월', inplace = True)

# %%
category_S_df_list[0].head()
# Out:
#             종목코드    종목명  시작일 기준가  종료일 종가     대비    등락률     거래량          거래대금
# 기준년월
# 2018-09-30  6840  AK홀딩스    61200   44600 -16600 -27.12  788157  3.947046e+10
# 2018-10-31  6840  AK홀딩스    44600   53200   8600  19.28  591482  2.885300e+10
# 2018-11-30  6840  AK홀딩스    53200   54000    800   1.50  405692  2.235991e+10
# 2018-12-31  6840  AK홀딩스    67200   61200  -6000  -8.93  508904  3.166795e+10
# 2019-01-31  6840  AK홀딩스    54000   51000  -3000  -5.56  365662  1.852218e+10

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [2018-09-30 00:00:00, 2018-10-31 00:00:00, 2018-11-30 00:00:00, 2018-12-31 00:00:00, 2019-01-31 00:00:00, 2019-02-28 00:00:00, 2019-03-31 00:00:00, 2019-04-30 00:00:00, 2019-05-31 00:00:00, 2019-06-30 00:00:00, 2019-07-31 00:00:00, 2019-08-31 00:00:00, 2019-09-30 00:00:00, 2019-10-31 00:00:00, 2019-11-30 00:00:00, 2019-12-31 00:00:00, 2020-01-31 00:00:00, 2020-02-29 00:00:00, 2020-03-31 00:00:00, 2020-04-30 00:00:00, 2020-05-31 00:00:00, 2020-06-30 00:00:00, 2020-07-31 00:00:00, 2020-08-31 00:00:00, 2020-09-30 00:00:00, 2020-10-31 00:00:00, 2020-11-30 00:00:00, 2020-12-31 00:00:00, 2021-01-31 00:00:00, 2021-02-28 00:00:00, 2021-03-31 00:00:00, 2021-04-30 00:00:00, 2021-05-31 00:00:00, 2021-06-30 00:00:00]

# %%
###종합 지수 = (비교 시점일 구성종목 평균 주가/기준 시점일 구성종목 평균 주가)*100 ###

def get_all_time_index(category, month):
    xlsx = pd.ExcelFile('C:/Users/user/Desktop/경진대회/관련종목.xlsx')
    inv_category = pd.read_excel(xlsx, sheet_name = category)
    category_list = inv_category['종목명'].tolist()

    category_df_list = []
    for i in range(len(category_list)):
        category_df_list.append(get_category(category_list[i], df_UD))

    S_df_list = []
    for S_list in category_df_list:
        S_df_list.append(pd.merge(df, S_list, on = '기준년월', how = 'left'))

    for df_list in S_df_list:
        df_list.fillna(0, inplace=True)

    price_9_1 = []
    for i in range(len(S_df_list)):
        price_9_1.append(S_df_list[i].iloc[0, 1])

    array = np.array(price_9_1)
    criteria_mean = array.mean()

    price = []
    for i in range(len(S_df_list)):
        price.append(S_df_list[i].iloc[month, 2])

    array2 = np.array(price)
    month_mean = array2.mean()

    all_time = (month_mean/criteria_mean)*100
    return all_time

def get_index_list(category):
    index_list = []
    for i in range(len(Timeindex)):
        index_list.append(get_all_time_index(category, i))
    df = pd.DataFrame(index_list, index = Timeindex, columns= ['종합지수'])
    return df

# %%
index_df_s = get_index_list('여가-스포츠');index_df_s
# Out:
#                   종합지수
# 기준년월
# 2018-09-30   81.491959
# 2018-10-31   89.021534
# 2018-11-30   85.587170
# 2018-12-31   99.160059
# 2019-01-31   89.495945
# 2019-02-28   80.369798
# 2019-03-31   82.912922
# 2019-04-30   84.464573
# 2019-05-31   91.861562
# 2019-06-30   91.394212
# 2019-07-31   95.220082
# 2019-08-31   87.456848
# 2019-09-30   87.634480
# 2019-10-31   79.393475
# 2019-11-30   78.733935
# 2019-12-31   80.897623
# 2020-01-31   81.902784
# 2020-02-29   87.777674
# 2020-03-31   97.761775
# 2020-04-30  103.815666
# 2020-05-31   77.199176
# 2020-06-30   66.056206
# 2020-07-31   79.847790
# 2020-08-31   83.766924
# 2020-09-30   81.338437
# 2020-10-31   86.314497
# 2020-11-30   89.024676
# 2020-12-31   89.351537
# 2021-01-31  110.825597
# 2021-02-28  116.730632
# 2021-03-31  122.953973
# 2021-04-30  111.619901
# 2021-05-31  121.772394
# 2021-06-30  125.938689

# %%
index_df_e = get_index_list('e상품-서비스');index_df_e
# Out:
#                   종합지수
# 기준년월
# 2018-09-30   86.895814
# 2018-10-31   92.971244
# 2018-11-30   88.531998
# 2018-12-31  109.770483
# 2019-01-31   91.471341
# 2019-02-28   91.623658
# 2019-03-31   92.336557
# 2019-04-30   94.954953
# 2019-05-31   93.847215
# 2019-06-30   95.065433
# 2019-07-31   99.159052
# 2019-08-31   92.561724
# 2019-09-30   94.766261
# 2019-10-31   89.164144
# 2019-11-30   89.634439
# 2019-12-31   90.825898
# 2020-01-31   94.208103
# 2020-02-29  110.198463
# 2020-03-31  119.447940
# 2020-04-30  130.694850
# 2020-05-31   88.563903
# 2020-06-30   80.375593
# 2020-07-31   92.709668
# 2020-08-31  103.201414
# 2020-09-30  105.262477
# 2020-10-31  108.469385
# 2020-11-30  114.235646
# 2020-12-31  115.526681
# 2021-01-31  139.068322
# 2021-02-28  141.108202
# 2021-03-31  146.382458
# 2021-04-30  136.539158
# 2021-05-31  141.235146
# 2021-06-30  146.484179

# %%
index_df_f = get_index_list('식품');index_df_f
# Out:
#                   종합지수
# 기준년월
# 2018-09-30   87.664069
# 2018-10-31   94.282146
# 2018-11-30   91.864149
# 2018-12-31  100.000000
# 2019-01-31   96.238585
# 2019-02-28   66.048461
# 2019-03-31   65.618038
# 2019-04-30   65.902518
# 2019-05-31   98.030389
# 2019-06-30  103.075431
# 2019-07-31  103.508352
# 2019-08-31   74.084220
# 2019-09-30   74.448912
# 2019-10-31   69.378141
# 2019-11-30   65.113925
# 2019-12-31   67.653982
# 2020-01-31   61.954626
# 2020-02-29   65.475779
# 2020-03-31   68.374171
# 2020-04-30   70.977819
# 2020-05-31   59.343483
# 2020-06-30   52.860171
# 2020-07-31   63.785933
# 2020-08-31   65.355401
# 2020-09-30   66.485241
# 2020-10-31   69.155590
# 2020-11-30   70.220079
# 2020-12-31   67.046569
# 2021-01-31   70.757203
# 2021-02-28   71.098965
# 2021-03-31   73.699707
# 2021-04-30   75.660044
# 2021-05-31   85.871352
# 2021-06-30   88.278588

# %%
index_df_j = get_index_list('전자');index_df_j
# Out:
#                   종합지수
# 기준년월
# 2018-09-30   84.133514
# 2018-10-31   85.540802
# 2018-11-30   81.004731
# 2018-12-31  100.086734
# 2019-01-31   88.980324
# 2019-02-28   93.687607
# 2019-03-31   92.084287
# 2019-04-30  101.571730
# 2019-05-31   92.562359
# 2019-06-30   95.780151
# 2019-07-31   99.032592
# 2019-08-31   88.156696
# 2019-09-30   93.039312
# 2019-10-31   88.606758
# 2019-11-30   87.761535
# 2019-12-31   90.803883
# 2020-01-31  100.985982
# 2020-02-29  128.509417
# 2020-03-31  150.266487
# 2020-04-30  175.571781
# 2020-05-31   96.109222
# 2020-06-30   78.915376
# 2020-07-31   93.066128
# 2020-08-31  103.148793
# 2020-09-30  110.804081
# 2020-10-31  126.353244
# 2020-11-30  129.544854
# 2020-12-31  135.299323
# 2021-01-31  181.951961
# 2021-02-28  180.993504
# 2021-03-31  183.893527
# 2021-04-30  191.565878
# 2021-05-31  185.536774
# 2021-06-30  195.659216

# %%
#종합지수 시각화
fig, ax = plt.subplots(figsize = (30, 6), ncols= 4)
ax[0].plot(index_df_s['종합지수'], 'ko--')
ax[0].set_title('여가스포츠 종합지수')
ax[0].set(ylim = (50, 200))
ax[1].plot(index_df_e['종합지수'], 'ko--')
ax[1].set_title('e상품서비스 종합지수')
ax[1].set(ylim = (50, 200))
ax[2].plot(index_df_f['종합지수'], 'ko--')
ax[2].set_title('식품 종합지수')
ax[2].set(ylim = (50, 200))
ax[3].plot(index_df_j['종합지수'], 'ko--')
ax[3].set_title('전자 종합지수')
ax[3].set(ylim = (50, 200))
fig.autofmt_xdate(rotation = 45)
plt.show()
