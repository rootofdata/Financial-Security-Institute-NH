# %%
import FinanceDataReader as fdr

# %%
df_krx=fdr.StockListing('KRX')
df_krx
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S                  전자부품 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 6945  000547   KOSPI  흥국화재2우B                       NaN
# 6946  000545   KOSPI    흥국화재우                       NaN
# 6947  003280   KOSPI     흥아해운                    해상 운송업
# 6948  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 6949  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# ...

# %%
f=fdr.DataReader('005930','2021')
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-01-04  81000  84400  80200  83000  38655276  0.024691
# 2021-01-05  81600  83900  81600  83900  35335669  0.010843
# 2021-01-06  83300  84500  82100  82200  42089013 -0.020262
# 2021-01-07  82800  84200  82700  82900  32644642  0.008516
# 2021-01-08  83300  90000  83000  88800  59013307  0.071170
# ...           ...    ...    ...    ...       ...       ...
# 2021-08-17  74000  75100  74000  74200  30944847 -0.002688
# 2021-08-18  73900  74600  73100  73900  29192631 -0.004043
# 2021-08-19  73500  74400  73100  73100  22166298 -0.010825
# 2021-08-20  73500  73900  72500  72700  22364803 -0.005472
# 2021-08-23  73300  73900  73000  73800   9956388  0.015131
#
# [160 rows x 6 columns]

# %%
df_krxd
df_krxd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-8897b9807208> in <module>
# ----> 1 df_krxd=fdr.DataListing('KRX')
#       2 df_krxd
#
# AttributeError: module 'FinanceDataReader' has no attribute 'DataListing'
