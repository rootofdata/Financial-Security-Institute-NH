# %%
import pandas as pd
import numpy as np
import os

# %%
path = 'C:/Users/seven/OneDrive/바탕 화면/Python Workspace/금융데이터경진대회/KRX 데이터/전종목 등락률/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]
file_list_py

df = pd.DataFrame()
Timeindex = pd.date_range('9/1/2018', periods= len(file_list_py), freq = 'M')
for i, time in zip(file_list_py,Timeindex):
    data = pd.read_csv(path + i, encoding= 'cp949')
    data_df = pd.DataFrame(data)
    data_df['기준년월'] = time
    df = pd.concat([df, data])
 
df_UD = df.reset_index(drop=True)

# %%
file_list
# Out:
# ['18.09.csv',
#  '18.10.csv',
#  '18.11.csv',
#  '18.12.csv',
#  '19.01.csv',
#  '19.02.csv',
#  '19.03.csv',
#  '19.04.csv',
#  '19.05.csv',
#  '19.06.csv',
#  '19.07.csv',
#  '19.08.csv',
#  '19.09.csv',
#  '19.10.csv',
#  '19.11.csv',
#  '19.12.csv',
#  '20.01.csv',
#  '20.02.csv',
#  '20.03.csv',
#  '20.04.csv',
#  '20.05.csv',
#  '20.06.csv',
#  '20.07.csv',
#  '20.08.csv',
#  '20.09.csv',
#  '20.10.csv',
#  '20.11.csv',
#  '20.12.csv',
#  '21.01.csv',
#  '21.02.csv',
#  '21.03.csv',
#  '21.04.csv',
#  '21.05.csv',
#  '21.06.csv']

# %%
df_UD
# Out:
#          종목코드      종목명  시작일 기준가  종료일 종가    대비    등락률       거래량          거래대금  \
# 0      060310       3S     3050    2675  -375 -12.30   2547678    7402690950
# 1      095570   AJ네트웍스     5260    6160   900  17.11   3015817   18823537620
# 2      068400    AJ렌터카    13700   13500  -200  -1.46  12640854  190930111700
# 3      006840    AK홀딩스    67200   61200 -6000  -8.93    508904   31667947700
# 4      054620   APS홀딩스     5590    5360  -230  -4.11    776635    4230233420
# ...       ...      ...      ...     ...   ...    ...       ...           ...
# 83223  000547  흥국화재2우B    30650   31700  1050   3.43    170573    5709730650
# 83224  000545    흥국화재우    10900   11300   400   3.67    410258    4818653600
# 83225  003280     흥아해운      258     258     0   0.00         0             0
# 83226  037440       희림     8430    8170  -260  -3.08  42158093  412374053670
# 83227  238490       힘스    11550   11750   200   1.73   1550006   18032130350
#
#             기준년월
# 0     2018-09-30
# ...

# %%
path = 'C:/Users/user/Desktop/경진대회/KRX 데이터/투자자별 순매수 (기관합계)/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]

df = pd.DataFrame()
Timeindex = pd.date_range('9/1/2018', periods= len(file_list_py), freq = 'M')
for i, time in zip(file_list_py,Timeindex):
    data = pd.read_csv(path + i, encoding= 'cp949')
    data_df = pd.DataFrame(data)
    data_df['기준년월'] = time
    df = pd.concat([df, data])
    
df_CO = df.reset_index(drop=True)

# %%
df_CO
# Out:
#          종목코드       종목명     거래량_매도     거래량_매수   거래량_순매수         거래대금_매도  \
# 0      207940  삼성바이오로직스     339660     671024    331364    169513698000
# 1      068270      셀트리온    2083034    2633027    549993    605763009000
# 2      096770   SK이노베이션    1056279    1606585    550306    212568763000
# 3      004170       신세계     370292     615050    244758    125310165500
# 4      010130      고려아연     198303     395532    197229     82307992500
# ...       ...       ...        ...        ...       ...             ...
# 77294  011170     롯데케미칼    1714614     592693  -1121921    464503419000
# 77295  051910      LG화학    1570873    1188321   -382552   1289180244000
# 77296  035720       카카오   42143561   39971905  -2171656   6324992923500
# 77297  352820       하이브    4003584    2707346  -1296238   1165502703037
# 77298  005930      삼성전자  156738703  143778289 -12960414  12729498022300
#
#               거래대금_매수       거래대금_순매수       기준년월
# 0        338158966000   168645268000 2018-09-30
# ...

# %%
path = 'C:/Users/seven/OneDrive/바탕 화면/Python Workspace/금융데이터경진대회/KRX 데이터/투자자별 순매수(개인)/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]

df = pd.DataFrame()
Timeindex = pd.date_range('9/1/2018', periods= len(file_list_py), freq = 'M')
for i, time in zip(file_list_py,Timeindex):
    data = pd.read_csv(path + i, encoding= 'cp949')
    data_df = pd.DataFrame(data)
    data_df['기준년월'] = time
    df = pd.concat([df, data])
 
df_INDI = df.reset_index(drop=True)

# %%
df_INDI
# Out:
#          종목코드         종목명    거래량_매도    거래량_매수  거래량_순매수        거래대금_매도  \
# 0      000660      SK하이닉스  15017755  22505473  7487718  1156726067600
# 1      009150        삼성전기   6069826   8785205  2715379   914902151000
# 2      005490       POSCO    980886   2064885  1083999   294895536000
# 3      005930        삼성전자  40820189  46400731  5580542  1884050133350
# 4      066570        LG전자   7153615  10207716  3054101   516045817100
# ...       ...         ...       ...       ...      ...            ...
# 81103  361610  SK아이이테크놀로지  10965273   8920070 -2045203  1748443737500
# 81104  000270          기아  33405876  29597122 -3808754  2983622151000
# 81105  096770     SK이노베이션  10157913   8621172 -1536741  2877298365500
# 81106  035420       NAVER   9900546   8752749 -1147797  3939601043000
# 81107  006400       삼성SDI   2850200   2025650  -824550  1871910308000
#
#              거래대금_매수      거래대금_순매수       기준년월
# 0      1718074007900  561347940300 2018-09-30
# ...

# %%
path = 'C:/Users/seven/OneDrive/바탕 화면/Python Workspace/금융데이터경진대회/KRX 데이터/투자자별 순매수(외국인)/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]

df = pd.DataFrame()
Timeindex = pd.date_range('9/1/2018', periods= len(file_list_py), freq = 'M')
for i, time in zip(file_list_py,Timeindex):
    data = pd.read_csv(path + i, encoding= 'cp949')
    data_df = pd.DataFrame(data)
    data_df['기준년월'] = time
    df = pd.concat([df, data])
 
df_FOR = df.reset_index(drop=True)

# %%
df_FOR
# Out:
#          종목코드    종목명    거래량_매도    거래량_매수  거래량_순매수        거래대금_매도  \
# 0      028260   삼성물산   4806605  10048704  5242099   616907303718
# 1      068270   셀트리온   2237922   3297530  1059608   650173286333
# 2      021240    코웨이   3034023   6037336  3003313   263694182724
# 3      215600    신라젠   3106536   5271018  2164482   283931901200
# 4      010950  S-Oil   1472476   2502945  1030469   188116396792
# ...       ...    ...       ...       ...      ...            ...
# 74801  011200    HMM  36788522  32167811 -4620711  1641262223200
# 74802  005490  POSCO   3738177   3117721  -620456  1285846658871
# 74803  005935  삼성전자우  11362217   8083602 -3278615   841471684972
# 74804  005930   삼성전자  88407195  83204560 -5202635  7160596584282
# 74805  035720    카카오  18461507  13350598 -5110909  2780287653960
#
#              거래대금_매수      거래대금_순매수       기준년월
# 0      1247299690218  630392386500 2018-09-30
# 1       966827931333  316654645000 2018-09-30
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame(index = Timeindex)
df.index.names = ['기준년월']
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [2018-09-30 00:00:00, 2018-10-31 00:00:00, 2018-11-30 00:00:00, 2018-12-31 00:00:00, 2019-01-31 00:00:00, 2019-02-28 00:00:00, 2019-03-31 00:00:00, 2019-04-30 00:00:00, 2019-05-31 00:00:00, 2019-06-30 00:00:00, 2019-07-31 00:00:00, 2019-08-31 00:00:00, 2019-09-30 00:00:00, 2019-10-31 00:00:00, 2019-11-30 00:00:00, 2019-12-31 00:00:00, 2020-01-31 00:00:00, 2020-02-29 00:00:00, 2020-03-31 00:00:00, 2020-04-30 00:00:00, 2020-05-31 00:00:00, 2020-06-30 00:00:00, 2020-07-31 00:00:00, 2020-08-31 00:00:00, 2020-09-30 00:00:00, 2020-10-31 00:00:00, 2020-11-30 00:00:00, 2020-12-31 00:00:00, 2021-01-31 00:00:00, 2021-02-28 00:00:00, 2021-03-31 00:00:00, 2021-04-30 00:00:00, 2021-05-31 00:00:00, 2021-06-30 00:00:00]

# %%
#관련 종목 추출 함수

def get_category(category, df):
    category_df = df[df['종목명'] == category]
    category_df = category_df[['종목명','시작일 기준가', '종료일 종가', '기준년월']]
    category_df.set_index('기준년월', inplace = True)
    return category_df

def get_plot_2(df, i, y):
    df_end = df[y]
    fig, ax = plt.subplots(1, 1, figsize = (8, 6))
    plt.plot(df_end, 'ko--')
    fig.autofmt_xdate(rotation = 45)
    ax.set_title(str(df['종목명'].unique()))
    plt.show()

# %%
Jeju = get_category('제주맥주', df_UD)
pd.merge(df, Jeju, on = '기준년월', how = 'left')
# Out:
#              종목명  시작일 기준가  종료일 종가
# 기준년월
# 2018-09-30   NaN      NaN     NaN
# 2018-10-31   NaN      NaN     NaN
# 2018-11-30   NaN      NaN     NaN
# 2018-12-31   NaN      NaN     NaN
# 2019-01-31   NaN      NaN     NaN
# 2019-02-28   NaN      NaN     NaN
# 2019-03-31   NaN      NaN     NaN
# 2019-04-30   NaN      NaN     NaN
# 2019-05-31   NaN      NaN     NaN
# 2019-06-30   NaN      NaN     NaN
# 2019-07-31   NaN      NaN     NaN
# 2019-08-31   NaN      NaN     NaN
# 2019-09-30   NaN      NaN     NaN
# 2019-10-31   NaN      NaN     NaN
# 2019-11-30   NaN      NaN     NaN
# 2019-12-31   NaN      NaN     NaN
# 2020-01-31   NaN      NaN     NaN
# 2020-02-29   NaN      NaN     NaN
# 2020-03-31   NaN      NaN     NaN
# 2020-04-30   NaN      NaN     NaN
# 2020-05-31   NaN      NaN     NaN
# 2020-06-30   NaN      NaN     NaN
# 2020-07-31   NaN      NaN     NaN
# 2020-08-31   NaN      NaN     NaN
# 2020-09-30   NaN      NaN     NaN
# 2020-10-31   NaN      NaN     NaN
# ...

# %%
#맷플롯립 한글 설정
import matplotlib.font_manager as fm
font_path = r'C:\Users\seven\OneDrive\바탕 화면\Python Workspace\네이버글꼴모음'
fontprop = fm.FontProperties(fname=font_path, size=18)

# %%
import pandas as pd
#matplotlib 패키지 한글 깨짐 처리 시작
import matplotlib.pyplot as plt
import platform
if platform.system() == 'Darwin': #맥
        plt.rc('font', family='AppleGothic') 
elif platform.system() == 'Windows': #윈도우
        plt.rc('font', family='Malgun Gothic') 
elif platform.system() == 'Linux': #리눅스 (구글 콜랩)
        #!wget "https://www.wfonts.com/download/data/2016/06/13/malgun-gothic/malgun.ttf"
        #!mv malgun.ttf /usr/share/fonts/truetype/
        #import matplotlib.font_manager as fm 
        #fm._rebuild() 
        plt.rc('font', family='Malgun Gothic') 
plt.rcParams['axes.unicode_minus'] = False #한글 폰트 사용시 마이너스 폰트 깨짐 해결
#matplotlib 패키지 한글 깨짐 처리 끝

# %%
xlsx = pd.ExcelFile('C:/Users/seven/OneDrive/바탕 화면/경진대회/관련종목.xlsx')
inv_category_S = pd.read_excel(xlsx, sheet_name = '여가-스포츠')
category_list_S = inv_category_S['종목명'].tolist()

# %%
xlsx = pd.ExcelFile('C:/Users/seven/OneDrive/바탕 화면/경진대회/관련종목.xlsx')
inv_category_E = pd.read_excel(xlsx, sheet_name = 'e상품-서비스')
category_list_E = inv_category_E['종목명'].tolist()

# %%
xlsx = pd.ExcelFile('C:/Users/seven/OneDrive/바탕 화면/경진대회/관련종목.xlsx')
inv_category_F = pd.read_excel(xlsx, sheet_name = '식품')
category_list_F = inv_category_F['종목명'].tolist()

# %%
xlsx = pd.ExcelFile('C:/Users/seven/OneDrive/바탕 화면/경진대회/관련종목.xlsx')
inv_category_J = pd.read_excel(xlsx, sheet_name = '식품')
category_list_J = inv_category_J['종목명'].tolist()

# %%
category_S_df_list = []
for i in range(len(category_list_S)):
    category_S_df_list.append(get_category(category_list_S[i], df_UD))

# %%
category_S_df_list[0].head()
# Out:
#               종목명  시작일 기준가  종료일 종가
# 기준년월
# 2018-09-30  AK홀딩스    67200   61200
# 2018-10-31  AK홀딩스    61200   44600
# 2018-11-30  AK홀딩스    44600   53200
# 2018-12-31  AK홀딩스    53200   54000
# 2019-01-31  AK홀딩스    54000   51000

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [2018-09-30 00:00:00, 2018-10-31 00:00:00, 2018-11-30 00:00:00, 2018-12-31 00:00:00, 2019-01-31 00:00:00, 2019-02-28 00:00:00, 2019-03-31 00:00:00, 2019-04-30 00:00:00, 2019-05-31 00:00:00, 2019-06-30 00:00:00, 2019-07-31 00:00:00, 2019-08-31 00:00:00, 2019-09-30 00:00:00, 2019-10-31 00:00:00, 2019-11-30 00:00:00, 2019-12-31 00:00:00, 2020-01-31 00:00:00, 2020-02-29 00:00:00, 2020-03-31 00:00:00, 2020-04-30 00:00:00, 2020-05-31 00:00:00, 2020-06-30 00:00:00, 2020-07-31 00:00:00, 2020-08-31 00:00:00, 2020-09-30 00:00:00, 2020-10-31 00:00:00, 2020-11-30 00:00:00, 2020-12-31 00:00:00, 2021-01-31 00:00:00, 2021-02-28 00:00:00, 2021-03-31 00:00:00, 2021-04-30 00:00:00, 2021-05-31 00:00:00, 2021-06-30 00:00:00]

# %%
###종합 지수 = (비교 시점일 구성종목 평균 주가/기준 시점일 구성종목 평균 주가)*100 ###

def get_all_time_index(category, month, n, m):
    xlsx = pd.ExcelFile('C:/Users/seven/OneDrive/바탕 화면/경진대회/관련종목.xlsx')
    inv_category = pd.read_excel(xlsx, sheet_name = category)
    category_list = inv_category['종목명'].tolist()

    category_df_list = []
    for i in range(len(category_list)):
        category_df_list.append(get_category(category_list[i], df_UD))

    S_df_list = []
    for S_list in category_df_list:
        S_df_list.append(pd.merge(df, S_list, on = '기준년월', how = 'left'))

    for df_list in S_df_list:
        df_list.fillna(0, inplace=True)

    price_9_1 = []
    for i in range(len(S_df_list)):
        price_9_1.append(S_df_list[i].iloc[0, 1])

    array = np.array(price_9_1)
    criteria_mean = array.mean()

    price = []
    for i in range(len(S_df_list)):
        price.append(S_df_list[i].iloc[month, 2])

    array2 = np.array(price)
    month_mean = array2.mean()

    all_time = (month_mean/criteria_mean)*100
    return all_time

def get_index_list(category):
    index_list = []
    for i in range(len(Timeindex)):
        index_list.append(get_all_time_index(category, i))
    df = pd.DataFrame(index_list, index = Timeindex, columns= ['종합지수'])
    return df

# %%
index_df_s = get_index_list('여가-스포츠');index_df_s

# %%
index_df_e = get_index_list('e상품-서비스');index_df_e

# %%
index_df_f = get_index_list('식품')
# Out:
#                   종합지수
# 기준년월
# 2018-09-30  101.859429
# 2018-10-31   89.294120
# 2018-11-30   96.035255
# 2018-12-31   93.572298
# 2019-01-31   98.028074
# 2019-02-28   99.853195
# 2019-03-31  104.992045
# 2019-04-30  105.433016
# 2019-05-31   75.461763
# 2019-06-30   75.833237
# 2019-07-31   70.668178
# 2019-08-31   66.324672
# 2019-09-30   68.911959
# 2019-10-31   67.276585
# 2019-11-30   66.838159
# 2019-12-31   67.127928
# 2020-01-31   63.106628
# 2020-02-29   60.446933
# 2020-03-31   53.843068
# 2020-04-30   64.971987
# 2020-05-31   66.570638
# 2020-06-30   67.721486
# 2020-07-31   70.441489
# 2020-08-31   71.525772
# 2020-09-30   68.293252
# 2020-10-31   66.693255
# 2020-11-30   69.645540
# 2020-12-31   72.297601
# 2021-01-31   72.072883
# 2021-02-28   72.421000
# 2021-03-31   75.070101
# 2021-04-30   77.066889
# 2021-05-31   87.468069
# 2021-06-30   89.920065

# %%
index_df_j = get_index_list('전자');index_df_j

# %%
#종합지수 시각화
data = pd.read_csv(r'C:\Users\seven\OneDrive\바탕 화면\경진대회\금융보안원_경진대회_데이터(최종제출).csv')

data['매출금액'] = data['매출금액']/10000
data.rename(columns={'매출금액' : '매출금액(단위:만원)'}, inplace=True)
#매출 건수 한 건당 매출금액 컬럼 추가
data['건당 매출금액(단위:만원)'] = data['매출금액(단위:만원)']/data['매출건수']

data_s = data[data['품목대분류명'] == '여가/스포츠']
data_j = data[data['품목대분류명'] == '전자']
data_f = data[data['품목대분류명'] == '식품']
data_e = data[data['품목대분류명'] == 'e상품/서비스']

fig, ax = plt.subplots(figsize = (20,15), ncols= 2, nrows = 4)
ax[0, 0].plot(index_df_s['종합지수'], 'ko--')
ax[0, 0].set_title('여가스포츠 종합지수')
ax[1, 0].plot(index_df_e['종합지수'], 'ko--')
ax[1, 0].set_title('e상품서비스 종합지수')
ax[2, 0].plot(index_df_f['종합지수'], 'ko--')
ax[2, 0].set_title('식품 종합지수')
ax[3, 0].plot(index_df_j['종합지수'], 'ko--')
ax[3, 0].set_title('전자 종합지수')
fig.autofmt_xdate(rotation = 45)
groupby_s = data_s['매출금액(단위:만원)'].groupby(data_s['기준년월']).sum()
dfs = pd.DataFrame(groupby_s)
dfs.reset_index(inplace = True) 
sns.barplot(x='기준년월',y='매출금액(단위:만원)',data=dfs,ax=ax[0, 1])
plt.title("여가/스포츠")

groupby_j = data_j['매출금액(단위:만원)'].groupby(data_j['기준년월']).sum()
dfj = pd.DataFrame(groupby_j)
dfj.reset_index(inplace = True) 
sns.barplot(x='기준년월',y='매출금액(단위:만원)',data=dfj,ax=ax[3, 1])
plt.title("전자")


groupby_f = data_f['매출금액(단위:만원)'].groupby(data_f['기준년월']).sum()
dff = pd.DataFrame(groupby_f)
dff.reset_index(inplace = True) 
sns.barplot(x='기준년월',y='매출금액(단위:만원)',data=dff,ax=ax[2, 1])
plt.title("식품")

groupby_e = data_e['매출금액(단위:만원)'].groupby(data_e['기준년월']).sum()
dfe = pd.DataFrame(groupby_e)
dfe.reset_index(inplace = True) 
sns.barplot(x='기준년월',y='매출금액(단위:만원)',data=dfe,ax=ax[1, 1])
plt.title("여가/스포츠, e상품/서비스, 식품,전자 순")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,15), ncols= 2, nrows = 4)
ax[0, 0].plot(index_df_s['종합지수'], 'ko--')
ax[0, 0].set_title('여가스포츠 종합지수')
ax[0, 0].set_xticks(Timeindex, str(Timeindex))
ax[1, 0].plot(index_df_e['종합지수'], 'ko--')
ax[1, 0].set_title('e상품서비스 종합지수')
ax[2, 0].plot(index_df_f['종합지수'], 'ko--')
ax[2, 0].set_title('식품 종합지수')
ax[3, 0].plot(index_df_j['종합지수'], 'ko--')
ax[3, 0].set_title('전자 종합지수')
fig.autofmt_xdate(rotation = 45)
groupby_s = data_s['매출금액(단위:만원)'].groupby(data_s['기준년월']).sum()
dfs = pd.DataFrame(groupby_s)
dfs.reset_index(inplace = True) 
sns.countplot(x='기준년월',data=data_s,ax=ax[0, 1])
plt.title("여가/스포츠")

groupby_j = data_j['매출금액(단위:만원)'].groupby(data_j['기준년월']).sum()
dfj = pd.DataFrame(groupby_j)
dfj.reset_index(inplace = True) 
sns.countplot(x='기준년월',data=data_j,ax=ax[3, 1])
plt.title("전자")


groupby_f = data_f['매출금액(단위:만원)'].groupby(data_f['기준년월']).sum()
dff = pd.DataFrame(groupby_f)
dff.reset_index(inplace = True) 
sns.countplot(x='기준년월',data=data_f,ax=ax[2, 1])
plt.title("식품")

groupby_e = data_e['매출금액(단위:만원)'].groupby(data_e['기준년월']).sum()
dfe = pd.DataFrame(groupby_e)
dfe.reset_index(inplace = True) 
sns.countplot(x='기준년월',data=data_e,ax=ax[1, 1])
plt.title("여가/스포츠, e상품/서비스, 식품,전자 순")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2, nrows= 5)
ax[0, 0].plot(index_df_s['종합지수'], 'ko--')
ax[0, 0].set_title('여가스포츠 종합지수')
ax[0, 0].set_xticks(Timeindex, str(Timeindex))
fig.autofmt_xdate(rotation = 45)
groupby_s = data_s['매출금액(단위:만원)'].groupby(data_s['기준년월']).sum()
dfs = pd.DataFrame(groupby_s)
dfs.reset_index(inplace = True) 
sns.countplot(x='기준년월',data=data_s,ax=ax[0, 1])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_e['종합지수'], 'ko--')
ax[0].set_title('e상품서비스 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
fig.autofmt_xdate(rotation = 45)
groupby_e = data_e['매출금액(단위:만원)'].groupby(data_e['기준년월']).sum()
dfs = pd.DataFrame(groupby_e)
dfs.reset_index(inplace = True) 
sns.countplot(x='기준년월',data=data_e,ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_j['종합지수'], 'ko--')
ax[0].set_title('전자 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
fig.autofmt_xdate(rotation = 45)
groupby_j = data_j['매출금액(단위:만원)'].groupby(data_j['기준년월']).sum()
dfs = pd.DataFrame(groupby_j)
dfs.reset_index(inplace = True) 
sns.countplot(x='기준년월',data=data_j,ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_f['종합지수'], 'ko--')
ax[0].set_title('식품 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
fig.autofmt_xdate(rotation = 45)
groupby_f = data_f['매출금액(단위:만원)'].groupby(data_f['기준년월']).sum()
dfs = pd.DataFrame(groupby_f)
dfs.reset_index(inplace = True) 
sns.countplot(x='기준년월',data=data_f,ax=ax[1])
plt.show()
# Out:
# <ipython-input-90-f5a52b192aeb>:4: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[0].set_xticks(Timeindex, str(Timeindex))

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_s['종합지수'], 'ko--')
ax[0].set_title('여가스포츠 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_s = data_s['매출금액(단위:만원)'].groupby(data_s['기준년월']).sum()
dfs = pd.DataFrame(groupby_s)
dfs.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dfs,ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_e['종합지수'], 'ko--')
ax[0].set_title('e상품서비스 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_e = data_e['매출금액(단위:만원)'].groupby(data_e['기준년월']).sum()
dfe = pd.DataFrame(groupby_e)
dfe.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dfe,ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_j['종합지수'], 'ko--')
ax[0].set_title('전자 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_j = data_j['매출금액(단위:만원)'].groupby(data_j['기준년월']).sum()
dfj = pd.DataFrame(groupby_j)
dfj.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dfj,ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_f['종합지수'], 'ko--')
ax[0].set_title('식품 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_f = data_f['매출금액(단위:만원)'].groupby(data_f['기준년월']).sum()
dff = pd.DataFrame(groupby_f)
dff.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dff,ax=ax[1])
plt.show()
# Out:
# <ipython-input-104-85cc993eb6ce>:4: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[0].set_xticks(Timeindex, str(Timeindex))

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_s['종합지수'], 'ko--')
ax[0].set_title('여가스포츠 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_s = data_s['매출건수'].groupby(data_s['기준년월']).sum()
dfs = pd.DataFrame(groupby_s)
dfs.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출건수',data=dfs,ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_e['종합지수'], 'ko--')
ax[0].set_title('e상품서비스 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_e = data_e['매출건수'].groupby(data_e['기준년월']).sum()
dfe = pd.DataFrame(groupby_e)
dfe.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출건수',data=dfe,ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_j['종합지수'], 'ko--')
ax[0].set_title('전자 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_j = data_j['매출건수'].groupby(data_j['기준년월']).sum()
dfj = pd.DataFrame(groupby_j)
dfj.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출건수',data=dfj,ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_f['종합지수'], 'ko--')
ax[0].set_title('식품 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_f = data_f['매출건수'].groupby(data_f['기준년월']).sum()
dff = pd.DataFrame(groupby_f)
dff.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출건수',data=dff,ax=ax[1])
plt.show()
# Out:
# <ipython-input-112-f80c1566417d>:4: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[0].set_xticks(Timeindex, str(Timeindex))

# %%
def get_all_time_index(category, month, iloc_n, iloc_m, df):
    xlsx = pd.ExcelFile('C:/Users/seven/OneDrive/바탕 화면/경진대회/관련종목.xlsx')
    inv_category = pd.read_excel(xlsx, sheet_name = category)
    category_list = inv_category['종목명'].tolist()

    category_df_list = []
    for i in range(len(category_list)):
        category_df_list.append(get_category(category_list[i], df))

    S_df_list = []
    for S_list in category_df_list:
        S_df_list.append(pd.merge(df, S_list, on = '기준년월', how = 'left'))

    for df_list in S_df_list:
        df_list.fillna(0, inplace=True)

    price_9_1 = []
    for i in range(len(S_df_list)):
        price_9_1.append(S_df_list[i].iloc[0, iloc_n])

    array = np.array(price_9_1)
    criteria_mean = array.mean()

    price = []
    for i in range(len(S_df_list)):
        price.append(S_df_list[i].iloc[month, iloc_m])

    array2 = np.array(price)
    month_mean = array2.mean()

    all_time = (month_mean/criteria_mean)*100
    return all_time

def get_index_list(category):
    index_list = []
    for i in range(len(Timeindex)):
        index_list.append(get_all_time_index(category, i))
    df = pd.DataFrame(index_list, index = Timeindex, columns= ['종합지수'])
    return df

# %%
def get_category(category, df):
    category_df = df[df['종목명'] == category]
    category_df = category_df[['종목명','거래량_순매수', '거래대금_순매수', '기준년월']]
    category_df.set_index('기준년월', inplace = True)
    return category_df

# %%
get_category('AK홀딩스', df_INDI)

# %%
category_list[1]
# Out:
# 'CJ CGV'

# %%
xlsx = pd.ExcelFile('C:/Users/seven/OneDrive/바탕 화면/경진대회/관련종목.xlsx')
inv_category = pd.read_excel(xlsx, sheet_name = '여가-스포츠')
category_list = inv_category['종목명'].tolist()

category_df_list = []
for i in range(len(category_list)):
    category_df_list.append(get_category(category_list[i], df_INDI))

# %%
def get_sum(category, month, df_s):
    xlsx = pd.ExcelFile('C:/Users/seven/OneDrive/바탕 화면/경진대회/관련종목.xlsx')
    inv_category = pd.read_excel(xlsx, sheet_name = category)
    category_list = inv_category['종목명'].tolist()

    df = pd.DataFrame(index = Timeindex)
    df.index.names = ['기준년월']

    category_df_list = []
    for i in range(len(category_list)):
        category_df_list.append(get_category(category_list[i], df_s))

    S_df_list = []
    for S_list in category_df_list:
        S_df_list.append(pd.merge(df, S_list, on = '기준년월', how = 'left'))

    for df_list in S_df_list:
        df_list.fillna(0, inplace=True)

    volume_list = []
    for volume in S_df_list:
        volume_list.append(volume.iloc[month,1])

    array = np.array(volume_list)
    n_sum = array.sum()

    return n_sum

def get_sum_list(category, df_s):
    index_list = []
    for i in range(len(Timeindex)):
        index_list.append(get_sum(category, i, df_s))
    df = pd.DataFrame(index_list, index = Timeindex, columns= ['종합지수'])
    return df

# %%
def get_category(category, df):
    category_df = df[df['종목명'] == category]
    category_df = category_df[['종목명','거래량_순매수', '거래대금_순매수', '기준년월']]
    category_df.set_index('기준년월', inplace = True)
    return category_df

# %%
index_df_s = get_sum_list('여가-스포츠', df_INDI)

# %%
index_df_j = get_sum_list('전자', df_INDI)

# %%
Timeindex = pd.date_range('9/1/2018', periods= len(file_list_py), freq = 'M')
indi_f = get_sum_list('식품', df_INDI)

# %%
indi_f
# Out:
#                   종합지수
# 기준년월
# 2019-03-31  -2129002.0
# 2019-09-30  51576916.0
# 2020-03-31 -16733069.0
# 2020-09-30   7824825.0
# 2021-03-31  -6625695.0

# %%
CO_df_e = get_sum_list('')

# %%
#개인
#indi_f = get_sum_list('식품', df_INDI)
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(CO_df_e['종합지수'], 'ko--')
ax[0].set_title('식품 거래량')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
fig.autofmt_xdate(rotation = 45)
groupby_f = data_f['매출금액(단위:만원)'].groupby(data_f['기준년월']).sum()
dff = pd.DataFrame(groupby_f)
dff.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dff,ax=ax[1])
plt.show()
# Out:
# <ipython-input-202-60b5dd7f5586>:6: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[0].set_xticks(Timeindex, str(Timeindex))

# %%
index_df_f
# Out:
#                   종합지수
# 기준년월
# 2018-09-30   3612669.0
# 2018-10-31  -4501802.0
# 2018-11-30  14073586.0
# 2018-12-31  -2898741.0
# 2019-01-31   -916561.0
# 2019-02-28   8231801.0
# 2019-03-31  -2129002.0
# 2019-04-30  17935828.0
# 2019-05-31  30485013.0
# 2019-06-30  -6706877.0
# 2019-07-31   5465369.0
# 2019-08-31  16161846.0
# 2019-09-30  51576916.0
# 2019-10-31    358469.0
# 2019-11-30   4427500.0
# 2019-12-31  28116989.0
# 2020-01-31  15107910.0
# 2020-02-29  34761762.0
# 2020-03-31 -16733069.0
# 2020-04-30  -7974597.0
# 2020-05-31  13463957.0
# 2020-06-30  11920107.0
# 2020-07-31   8790754.0
# 2020-08-31  -2750881.0
# 2020-09-30   7824825.0
# 2020-10-31  18335122.0
# 2020-11-30  11731687.0
# 2020-12-31  19927463.0
# 2021-01-31  19399938.0
# 2021-02-28  24167486.0
# 2021-03-31  -6625695.0
# 2021-04-30   9300073.0
# 2021-05-31   1301295.0
# 2021-06-30   8921789.0

# %%
#종합지수
index_df_f = get_index_list('식품')

fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_f['종합지수'], 'ko--')
ax[0].set_title('식품 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_f = data_f['매출금액(단위:만원)'].groupby(data_f['기준년월']).sum()
dff = pd.DataFrame(groupby_f)
dff.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dff,ax=ax[1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-206-3022d28d5f48> in <module>
#       1 #종합지수
# ----> 2 index_df_f = get_all_time_index('식품');index_df_f
#       3
#       4 fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
#       5 ax[0].plot(index_df_f['종합지수'], 'ko--')
#
# TypeError: get_all_time_index() missing 1 required positional argument: 'month'

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_s['종합지수'], 'ko--')
ax[0].set_title('여가스포츠 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_s = data_s['매출금액(단위:만원)'].groupby(data_s['기준년월']).sum()
dfs = pd.DataFrame(groupby_s)
dfs.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dfs,ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_j['종합지수'], 'ko--')
ax[0].set_title('전자 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_j = data_j['매출금액(단위:만원)'].groupby(data_j['기준년월']).sum()
dfj = pd.DataFrame(groupby_j)
dfj.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dfj,ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(index_df_e['종합지수'], 'ko--')
ax[0].set_title('e상품서비스 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_e = data_e['매출금액(단위:만원)'].groupby(data_e['기준년월']).sum()
dfe = pd.DataFrame(groupby_e)
dfe.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dfe,ax=ax[1])
plt.show()

# %%
df_s_CO = get_sum_list('여가-스포츠', df_CO)
df_j_CO = get_sum_list('전자', df_CO)
df_e_CO = get_sum_list('e상품-서비스', df_CO)
df_f_CO = get_sum_list('식품', df_CO)

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(df_s_CO['종합지수'], 'ko--')
ax[0].set_title('여가스포츠 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_f = data_f['매출금액(단위:만원)'].groupby(data_f['기준년월']).sum()
dff = pd.DataFrame(groupby_f)
dff.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dff,ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(df_j_CO['종합지수'], 'ko--')
ax[0].set_title('전자 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_f = data_f['매출금액(단위:만원)'].groupby(data_f['기준년월']).sum()
dff = pd.DataFrame(groupby_f)
dff.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dff,ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2)
ax[0].plot(df_e_CO['종합지수'], 'ko--')
ax[0].set_title('e상품서비스 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
fig.autofmt_xdate(rotation = 45)
groupby_f = data_f['매출금액(단위:만원)'].groupby(data_f['기준년월']).sum()
dff = pd.DataFrame(groupby_f)
dff.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dff,ax=ax[1])
plt.show()

# %%
def get_plot(df_f, data, category, category2):
    fig, ax = plt.subplots(figsize = (18,12), ncols= 2, nrows = 4)
    #종합지수
    ax[0, 0].plot(df_f['종합지수'], 'ko--')
    ax[0, 0].set_title(category+' 종합지수')
    ax[0, 0].set_xticks(Timeindex, str(Timeindex))
    ax[0, 0].grid(True)
    from datetime import datetime

    crisis_data = [
        (datetime(2019, 3, 1), '1st'),
        (datetime(2019, 9, 1), '2nd'),
        (datetime(2020, 3, 1), '3rd'),
        (datetime(2020, 9, 1), '4th'),
        (datetime(2021, 3, 1), '5th')
    ]
    spx = df_f['종합지수']
    for date, label in crisis_data:
        ax[0, 0].annotate(label, xy = (date, spx.asof(date) + 75), #annotate : x, y로 지정한 위치에 라벨을 추가
        xytext = (date, spx.asof(date) + 225),
        arrowprops = dict(facecolor = 'black', headwidth = 6, width = 4, headlength = 6),
        horizontalalignment = 'left', verticalalignment = 'top')
    fig.autofmt_xdate(rotation = 45)
    
    #개인
    indi_df = get_sum_list(category2, df_INDI)
    ax[1, 0].plot(indi_df['거래량_순매수'], 'ko--')
    ax[1, 0].set_title(category+' 종합지수')
    ax[1, 0].set_xticks(Timeindex, str(Timeindex))
    ax[1, 0].grid(True)
    spx = indi_df['거래량_순매수']
    for date, label in crisis_data:
        ax[1, 0].annotate(label, xy = (date, spx.asof(date) + 75), #annotate : x, y로 지정한 위치에 라벨을 추가
        xytext = (date, spx.asof(date) + 225),
        arrowprops = dict(facecolor = 'black', headwidth = 6, width = 4, headlength = 6),
        horizontalalignment = 'left', verticalalignment = 'top')
    fig.autofmt_xdate(rotation = 45)

    #기관
    indi_df = get_sum_list(category2, df_CO)
    ax[2, 0].plot(indi_df['거래량_순매수'], 'ko--')
    ax[2, 0].set_title(category+' 종합지수')
    ax[2, 0].set_xticks(Timeindex, str(Timeindex))
    ax[2, 0].grid(True)
    spx = indi_df['거래량_순매수']
    for date, label in crisis_data:
        ax[2, 0].annotate(label, xy = (date, spx.asof(date) + 75), #annotate : x, y로 지정한 위치에 라벨을 추가
        xytext = (date, spx.asof(date) + 225),
        arrowprops = dict(facecolor = 'black', headwidth = 6, width = 4, headlength = 6),
        horizontalalignment = 'left', verticalalignment = 'top')
    fig.autofmt_xdate(rotation = 45)

    #외국인
    indi_df = get_sum_list(category2, df_FOR)
    ax[3, 0].plot(indi_df['거래량_순매수'], 'ko--')
    ax[3, 0].set_title(category + ' 종합지수')
    ax[3, 0].set_xticks(Timeindex, str(Timeindex))
    ax[3, 0].grid(True)
    spx = indi_df['거래량_순매수']
    for date, label in crisis_data:
        ax[3, 0].annotate(label, xy = (date, spx.asof(date) + 75), #annotate : x, y로 지정한 위치에 라벨을 추가
        xytext = (date, spx.asof(date) + 225),
        arrowprops = dict(facecolor = 'black', headwidth = 6, width = 4, headlength = 6),
        horizontalalignment = 'left', verticalalignment = 'top')
    fig.autofmt_xdate(rotation = 45)




    #barplot
    grouped = data['매출금액(단위:만원)'].groupby(data['기준년월']).sum()
    dff = pd.DataFrame(grouped)
    dff.reset_index(inplace = True) 
    sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dff,ax=ax[0, 1])
    plt.show()

# %%
get_plot(index_df_f, data_f, '식품', '식품')
# Out:
# <ipython-input-191-39e7c693622b>:6: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[0, 0].set_xticks(Timeindex, str(Timeindex))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
fig, ax = plt.subplots(figsize = (18,12), ncols= 2, ncol = 5)
ax[0].plot(df_f_CO['종합지수'], 'ko--')
ax[0].set_title('식품 종합지수')
ax[0].set_xticks(Timeindex, str(Timeindex))
ax[0].grid(True)
from datetime import datetime

crisis_data = [
    (datetime(2019, 3, 1), '1st'),
    (datetime(2019, 9, 1), '2nd'),
    (datetime(2020, 3, 1), '3rd'),
    (datetime(2020, 9, 1), '4th'),
    (datetime(2021, 3, 1), '5th')
]

spx = df_f_CO['종합지수']
for date, label in crisis_data:
    ax[0].annotate(label, xy = (date, spx.asof(date) + 75), #annotate : x, y로 지정한 위치에 라벨을 추가
    xytext = (date, spx.asof(date) + 225),
    arrowprops = dict(facecolor = 'black', headwidth = 6, width = 4, headlength = 6),
    horizontalalignment = 'left', verticalalignment = 'top')
fig.autofmt_xdate(rotation = 45)
groupby_f = data_f['매출금액(단위:만원)'].groupby(data_f['기준년월']).sum()
dff = pd.DataFrame(groupby_f)
dff.reset_index(inplace = True) 
sns.barplot(x='기준년월', y = '매출금액(단위:만원)',data=dff,ax=ax[1])
plt.show()
# Out:
# <ipython-input-183-4c03dc37f65a>:4: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[0].set_xticks(Timeindex, str(Timeindex))

# %%
Timeindex2 = pd.date_range('3/1/2019', periods= 5, freq = '6M')

# %%
Timeindex
# Out:
# DatetimeIndex(['2019-03-31', '2019-09-30', '2020-03-31', '2020-09-30',
#                '2021-03-31'],
#               dtype='datetime64[ns]', freq='6M')

# %%
from datetime import datetime

crisis_data = [
    (datetime(2019, 3, 31), '1st'),
    (datetime(2019, 9, 30), '2nd'),
    (datetime(2020, 3, 31), '3rd'),
    (datetime(2020, 9, 30), '4th'),
    (datetime(2021, 3, 31), '5th')
]

spx = df_f_CO['종합지수']
for date, label in crisis_data:
    ax[0].annotate(label, xy = (date, spx.asof(date) + 75), #annotate : x, y로 지정한 위치에 라벨을 추가
    xytext = (date, spx.asof(date) + 225),
    arrowprops = dict(facecolor = 'black', headwidth = 4, width = 2, headlength = 4),
    horizontalalignment = 'left', verticalalignment = 'top')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-180-6b579e3c5140> in <module>
#       1 crisis_data = [
# ----> 2     (datetime(2019, 3, 31), '1st'),
#       3     (datetime(2019, 9, 30), '2nd'),
#       4     (datetime(2020, 3, 31), '3rd'),
#       5     (datetime(2020, 9, 30), '4th'),
#
# NameError: name 'datetime' is not defined
