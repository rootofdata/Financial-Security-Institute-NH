# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
data = pd.read_csv(r'C:\Users\seven\OneDrive\바탕 화면\경진대회\금융보안원_경진대회_데이터(최종제출).csv')

# %%
data.head()
# Out:
#      기준년월  품목대분류코드   품목대분류명  품목중분류코드   품목중분류명  성별   연령   가구생애주기 고객소재지_광역시도  \
# 0  201903       10       의류     1010     여성의류  여성  40대  초중고자녀가구      서울특별시
# 1  201903       21  e상품/서비스     2110   o2o서비스  여성  20대  신혼영유아가구      서울특별시
# 2  201903       19    출산/육아     1913  육아용품서비스  여성  30대  신혼영유아가구      서울특별시
# 3  201903       21  e상품/서비스     2111  e머니/상품권  여성  30대  신혼영유아가구      서울특별시
# 4  201903       17       생활     1710     생활용품  여성  30대  신혼영유아가구      서울특별시
#
#   고객소재지_시군구 고객소재지_읍면동     매출금액  매출건수
# 0       구로구        궁동   782521    13
# 1       구로구        궁동   963789    29
# 2       구로구        궁동   924309    46
# 3       구로구        궁동  1089360    54
# 4       구로구        궁동  1656740    58

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519297 entries, 0 to 519296
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   기준년월        519297 non-null  int64
#  1   품목대분류코드     519297 non-null  int64
#  2   품목대분류명      519297 non-null  object
#  3   품목중분류코드     519297 non-null  int64
#  4   품목중분류명      519297 non-null  object
#  5   성별          519297 non-null  object
#  6   연령          519297 non-null  object
#  7   가구생애주기      519297 non-null  object
#  8   고객소재지_광역시도  519297 non-null  object
#  9   고객소재지_시군구   519297 non-null  object
#  10  고객소재지_읍면동   519297 non-null  object
#  11  매출금액        519297 non-null  int64
#  12  매출건수        519297 non-null  int64
# dtypes: int64(5), object(8)
# memory usage: 51.5+ MB

# %%
data[['매출금액', '매출건수']].describe()
# Out:
#                매출금액           매출건수
# count  5.192970e+05  519297.000000
# mean   2.188457e+06      48.958860
# std    6.438257e+06     163.855617
# min    1.490000e+03       4.000000
# 25%    3.412650e+05       9.000000
# 50%    7.628000e+05      17.000000
# 75%    1.878443e+06      38.000000
# max    5.918488e+08   11811.000000

# %%
data_df = pd.DataFrame(data)

# %%
data_df['성별'].value_counts()
# Out:
# 여성    330244
# 남성    189053
# Name: 성별, dtype: int64

# %%
data_df['매출금액'] = data_df['매출금액']/10000
data_df
# Out:
#           기준년월  품목대분류코드   품목대분류명  품목중분류코드   품목중분류명  성별      연령   가구생애주기  \
# 0       201903       10       의류     1010     여성의류  여성     40대  초중고자녀가구
# 1       201903       21  e상품/서비스     2110   o2o서비스  여성     20대  신혼영유아가구
# 2       201903       19    출산/육아     1913  육아용품서비스  여성     30대  신혼영유아가구
# 3       201903       21  e상품/서비스     2111  e머니/상품권  여성     30대  신혼영유아가구
# 4       201903       17       생활     1710     생활용품  여성     30대  신혼영유아가구
# ...        ...      ...      ...      ...      ...  ..     ...      ...
# 519292  202103       20   여가/스포츠     2013       여행  여성     30대     1인가구
# 519293  202103       21  e상품/서비스     2110   o2o서비스  남성     30대     1인가구
# 519294  202103       11     패션잡화     1113   시계/주얼리  여성     30대  신혼영유아가구
# 519295  202103       16       식품     1610     가공식품  남성     40대  초중고자녀가구
# 519296  202103       21  e상품/서비스     2110   o2o서비스  여성  60대 이상     노인가구
#
#        고객소재지_광역시도 고객소재지_시군구 고객소재지_읍면동      매출금액  매출건수
# 0           서울특별시       구로구        궁동   78.2521    13
# 1           서울특별시       구로구        궁동   96.3789    29
# 2           서울특별시       구로구        궁동   92.4309    46
# 3           서울특별시       구로구        궁동  108.9360    54
# 4           서울특별시       구로구        궁동  165.6740    58
# ...           ...       ...       ...       ...   ...
# 519292      서울특별시      영등포구    영등포동7가  141.1368     7
# 519293      서울특별시      영등포구    영등포동7가  138.6040    63
# 519294      서울특별시      영등포구    영등포동7가   39.0818     7
# 519295      서울특별시      영등포구    영등포동7가   32.7592     7
# 519296      서울특별시      영등포구    영등포동8가   92.6404    10
#
# [519297 rows x 13 columns]

# %%
import seaborn as sns

# %%
data_L_M = data_df[['기준년월','품목대분류명', '매출금액']]
data_L_M
# Out:
#           기준년월   품목대분류명      매출금액
# 0       201903       의류   78.2521
# 1       201903  e상품/서비스   96.3789
# 2       201903    출산/육아   92.4309
# 3       201903  e상품/서비스  108.9360
# 4       201903       생활  165.6740
# ...        ...      ...       ...
# 519292  202103   여가/스포츠  141.1368
# 519293  202103  e상품/서비스  138.6040
# 519294  202103     패션잡화   39.0818
# 519295  202103       식품   32.7592
# 519296  202103  e상품/서비스   92.6404
#
# [519297 rows x 3 columns]

# %%
grouped_L_M = data_L_M['매출금액'].groupby(data_L_M['품목대분류명']).sum()
grouped_L_M
# Out:
# 품목대분류명
# e상품/서비스    4.541755e+07
# 가구         1.276486e+06
# 건강         4.943765e+06
# 기타         1.012914e+06
# 뷰티         3.251842e+06
# 생활         5.858030e+06
# 식품         1.029924e+07
# 여가/스포츠     1.486947e+07
# 의류         5.319929e+06
# 인테리어       1.881305e+06
# 전자         9.269736e+06
# 출산/육아      5.897862e+06
# 패션잡화       4.347801e+06
# Name: 매출금액, dtype: float64

# %%
df_g_L_M = pd.DataFrame(grouped_L_M)
df_g_L_M
# Out:
#                  매출금액
# 품목대분류명
# e상품/서비스  4.541755e+07
# 가구       1.276486e+06
# 건강       4.943765e+06
# 기타       1.012914e+06
# 뷰티       3.251842e+06
# 생활       5.858030e+06
# 식품       1.029924e+07
# 여가/스포츠   1.486947e+07
# 의류       5.319929e+06
# 인테리어     1.881305e+06
# 전자       9.269736e+06
# 출산/육아    5.897862e+06
# 패션잡화     4.347801e+06

# %%
df_g_L_M.rename(columns={'매출금액':'매출합계'}, inplace = True)
df_g_L_M.reset_index(inplace=True)
df_g_L_M.rename(columns= {'품목대분류명' : 'largecategory', '매출합계' : 'Total'}, inplace= True)
df_g_L_M
# Out:
#    largecategory         Total
# 0        e상품/서비스  4.541755e+07
# 1             가구  1.276486e+06
# 2             건강  4.943765e+06
# 3             기타  1.012914e+06
# 4             뷰티  3.251842e+06
# 5             생활  5.858030e+06
# 6             식품  1.029924e+07
# 7         여가/스포츠  1.486947e+07
# 8             의류  5.319929e+06
# 9           인테리어  1.881305e+06
# 10            전자  9.269736e+06
# 11         출산/육아  5.897862e+06
# 12          패션잡화  4.347801e+06

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['font.size'] = 23
plt.rcParams['figure.figsize'] = (10, 8)

# %%
sns.barplot(x = 'largecategory', y = 'Total', data = df_g_L_M)
# Out:
# <AxesSubplot:xlabel='largecategory', ylabel='Total'>

# %%
data_L_C = data_df[['품목대분류명', '매출건수']]
data_L_C
# Out:
#          품목대분류명  매출건수
# 0            의류    13
# 1       e상품/서비스    29
# 2         출산/육아    46
# 3       e상품/서비스    54
# 4            생활    58
# ...         ...   ...
# 519292   여가/스포츠     7
# 519293  e상품/서비스    63
# 519294     패션잡화     7
# 519295       식품     7
# 519296  e상품/서비스    10
#
# [519297 rows x 2 columns]

# %%
grouped_L_C = data_L_C['매출건수'].groupby(data_L_C['품목대분류명']).sum()
grouped_L_C
# Out:
# 품목대분류명
# e상품/서비스    12109299
# 가구           135554
# 건강           890922
# 기타           291332
# 뷰티           801723
# 생활          1604069
# 식품          2904327
# 여가/스포츠      2388971
# 의류           901036
# 인테리어         334541
# 전자           959948
# 출산/육아       1397660
# 패션잡화         704807
# Name: 매출건수, dtype: int64

# %%
df_L_C = pd.DataFrame(grouped_L_C);df_L_C
# Out:
#              매출건수
# 품목대분류명
# e상품/서비스  12109299
# 가구         135554
# 건강         890922
# 기타         291332
# 뷰티         801723
# 생활        1604069
# 식품        2904327
# 여가/스포츠    2388971
# 의류         901036
# 인테리어       334541
# 전자         959948
# 출산/육아     1397660
# 패션잡화       704807

# %%
df_L_C.reset_index(inplace=True)
df_L_C.rename(columns={'품목대분류명':'largecategory', '매출건수':'Total'}, inplace=True)
df_L_C
# Out:
#    largecategory     Total
# 0        e상품/서비스  12109299
# 1             가구    135554
# 2             건강    890922
# 3             기타    291332
# 4             뷰티    801723
# 5             생활   1604069
# 6             식품   2904327
# 7         여가/스포츠   2388971
# 8             의류    901036
# 9           인테리어    334541
# 10            전자    959948
# 11         출산/육아   1397660
# 12          패션잡화    704807

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 8))
sns.barplot(x = 'largecategory', y = 'Total', data = df_L_C)
fig.autofmt_xdate(rotation = 45)

# %%
data_L_M.set_index('기준년월', inplace=True)

# %%
data_L_M
# Out:
#          품목대분류명      매출금액
# 기준년월
# 201903       의류   78.2521
# 201903  e상품/서비스   96.3789
# 201903    출산/육아   92.4309
# 201903  e상품/서비스  108.9360
# 201903       생활  165.6740
# ...         ...       ...
# 202103   여가/스포츠  141.1368
# 202103  e상품/서비스  138.6040
# 202103     패션잡화   39.0818
# 202103       식품   32.7592
# 202103  e상품/서비스   92.6404
#
# [519297 rows x 2 columns]

# %%
df_L_M1903 = data_L_M.loc[201903]
df_L_M1909 = data_L_M.loc[201909]
df_L_M2003 = data_L_M.loc[202003]
df_L_M2009 = data_L_M.loc[202009]
df_L_M2103 = data_L_M.loc[202103]

# %%
dfset = [df_L_M1903, df_L_M1909, df_L_M2003, df_L_M2009, df_L_M2103]
for df in dfset:
    df.rename(columns={'매출금액':'매출합계'}, inplace = True)
    df.reset_index(inplace=True)
    df.rename(columns= {'품목대분류명' : 'largecategory', '매출합계' : 'Total_Money'}, inplace= True)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_L_M1903
# Out:
#          기준년월 largecategory  Total_Money
# 0      201903            의류      78.2521
# 1      201903       e상품/서비스      96.3789
# 2      201903         출산/육아      92.4309
# 3      201903       e상품/서비스     108.9360
# 4      201903            생활     165.6740
# ...       ...           ...          ...
# 68256  201903            의류     126.0455
# 68257  201903         출산/육아     289.4378
# 68258  201903       e상품/서비스    1327.6210
# 68259  201903        여가/스포츠      22.3538
# 68260  201903            의류      83.5484
#
# [68261 rows x 3 columns]

# %%
sns.barplot(x = 'largecategory', y = 'Total_Money', data = df_L_M1903)
# Out:
# <AxesSubplot:xlabel='largecategory', ylabel='Total_Money'>

# %%
sns.barplot(x = 'largecategory', y = 'Total_Money', data = df_L_M1903)
# Out:
# <AxesSubplot:xlabel='largecategory', ylabel='Total_Money'>

# %%
sns.barplot(x = 'largecategory', y = 'Total_Money', data = df_L_M2003)
# Out:
# <AxesSubplot:xlabel='largecategory', ylabel='Total_Money'>

# %%
sns.barplot(x = 'largecategory', y = 'Total_Money', data = df_L_M2009)
# Out:
# <AxesSubplot:xlabel='largecategory', ylabel='Total_Money'>

# %%
sns.barplot(x = 'largecategory', y = 'Total_Money', data = df_L_M2103)
# Out:
# <AxesSubplot:xlabel='largecategory', ylabel='Total_Money'>

# %%
data_df
# Out:
#           기준년월  품목대분류코드   품목대분류명  품목중분류코드   품목중분류명  성별      연령   가구생애주기  \
# 0       201903       10       의류     1010     여성의류  여성     40대  초중고자녀가구
# 1       201903       21  e상품/서비스     2110   o2o서비스  여성     20대  신혼영유아가구
# 2       201903       19    출산/육아     1913  육아용품서비스  여성     30대  신혼영유아가구
# 3       201903       21  e상품/서비스     2111  e머니/상품권  여성     30대  신혼영유아가구
# 4       201903       17       생활     1710     생활용품  여성     30대  신혼영유아가구
# ...        ...      ...      ...      ...      ...  ..     ...      ...
# 519292  202103       20   여가/스포츠     2013       여행  여성     30대     1인가구
# 519293  202103       21  e상품/서비스     2110   o2o서비스  남성     30대     1인가구
# 519294  202103       11     패션잡화     1113   시계/주얼리  여성     30대  신혼영유아가구
# 519295  202103       16       식품     1610     가공식품  남성     40대  초중고자녀가구
# 519296  202103       21  e상품/서비스     2110   o2o서비스  여성  60대 이상     노인가구
#
#        고객소재지_광역시도 고객소재지_시군구 고객소재지_읍면동      매출금액  매출건수
# 0           서울특별시       구로구        궁동   78.2521    13
# 1           서울특별시       구로구        궁동   96.3789    29
# 2           서울특별시       구로구        궁동   92.4309    46
# 3           서울특별시       구로구        궁동  108.9360    54
# 4           서울특별시       구로구        궁동  165.6740    58
# ...           ...       ...       ...       ...   ...
# 519292      서울특별시      영등포구    영등포동7가  141.1368     7
# 519293      서울특별시      영등포구    영등포동7가  138.6040    63
# 519294      서울특별시      영등포구    영등포동7가   39.0818     7
# 519295      서울특별시      영등포구    영등포동7가   32.7592     7
# 519296      서울특별시      영등포구    영등포동8가   92.6404    10
#
# [519297 rows x 13 columns]

# %%
dfLM = data_df[['기준년월', '품목대분류명','품목중분류명','매출금액']]
dfLM
# Out:
#           기준년월   품목대분류명   품목중분류명      매출금액
# 0       201903       의류     여성의류   78.2521
# 1       201903  e상품/서비스   o2o서비스   96.3789
# 2       201903    출산/육아  육아용품서비스   92.4309
# 3       201903  e상품/서비스  e머니/상품권  108.9360
# 4       201903       생활     생활용품  165.6740
# ...        ...      ...      ...       ...
# 519292  202103   여가/스포츠       여행  141.1368
# 519293  202103  e상품/서비스   o2o서비스  138.6040
# 519294  202103     패션잡화   시계/주얼리   39.0818
# 519295  202103       식품     가공식품   32.7592
# 519296  202103  e상품/서비스   o2o서비스   92.6404
#
# [519297 rows x 4 columns]

# %%
def get_barplot_M(category):
    dfLM_bar = dfLM[dfLM['품목대분류명'] == category]
    sns.barplot(x = '품목중분류명', y = '매출금액', hue = '기준년월', data = dfLM_bar)

# %%
get_barplot_M('전자')

# %%
get_barplot_M('여가/스포츠')

# %%
get_barplot_M('식품')

# %%
get_barplot_M('e상품/서비스')

# %%
def get_barplot_C(category):
    dfLC = data_df[['기준년월', '품목대분류명','품목중분류명','매출건수']]
    dfLC
    dfLC_bar = dfLC[dfLC['품목대분류명'] == category]
    sns.barplot(x = '품목중분류명', y = '매출건수', hue = '기준년월', data = dfLC_bar)

# %%
get_barplot_C('전자')

# %%
get_barplot_C('e상품/서비스')

# %%
get_barplot_C('여가/스포츠')

# %%
get_barplot_C('식품')

# %%
get_barplot_M('의류')

# %%
get_barplot_M('생활')

# %%
get_barplot_M('뷰티')

# %%
get_barplot_M('건강')

# %%
get_barplot_M('패션잡화')

# %%
get_barplot_M('인테리어')

# %%
get_barplot_M('출산/육아')

# %%
get_barplot_M('가구')

# %%
data_df['품목대분류명'].value_counts()
# Out:
# e상품/서비스    76052
# 여가/스포츠     67231
# 식품         64995
# 출산/육아      46009
# 의류         44431
# 패션잡화       40512
# 생활         39284
# 뷰티         38289
# 전자         33448
# 건강         23750
# 인테리어       20053
# 가구         12654
# 기타         12589
# Name: 품목대분류명, dtype: int64

# %%
data_df
# Out:
#           기준년월  품목대분류코드   품목대분류명  품목중분류코드   품목중분류명  성별      연령   가구생애주기  \
# 0       201903       10       의류     1010     여성의류  여성     40대  초중고자녀가구
# 1       201903       21  e상품/서비스     2110   o2o서비스  여성     20대  신혼영유아가구
# 2       201903       19    출산/육아     1913  육아용품서비스  여성     30대  신혼영유아가구
# 3       201903       21  e상품/서비스     2111  e머니/상품권  여성     30대  신혼영유아가구
# 4       201903       17       생활     1710     생활용품  여성     30대  신혼영유아가구
# ...        ...      ...      ...      ...      ...  ..     ...      ...
# 519292  202103       20   여가/스포츠     2013       여행  여성     30대     1인가구
# 519293  202103       21  e상품/서비스     2110   o2o서비스  남성     30대     1인가구
# 519294  202103       11     패션잡화     1113   시계/주얼리  여성     30대  신혼영유아가구
# 519295  202103       16       식품     1610     가공식품  남성     40대  초중고자녀가구
# 519296  202103       21  e상품/서비스     2110   o2o서비스  여성  60대 이상     노인가구
#
#        고객소재지_광역시도 고객소재지_시군구 고객소재지_읍면동      매출금액  매출건수
# 0           서울특별시       구로구        궁동   78.2521    13
# 1           서울특별시       구로구        궁동   96.3789    29
# 2           서울특별시       구로구        궁동   92.4309    46
# 3           서울특별시       구로구        궁동  108.9360    54
# 4           서울특별시       구로구        궁동  165.6740    58
# ...           ...       ...       ...       ...   ...
# 519292      서울특별시      영등포구    영등포동7가  141.1368     7
# 519293      서울특별시      영등포구    영등포동7가  138.6040    63
# 519294      서울특별시      영등포구    영등포동7가   39.0818     7
# 519295      서울특별시      영등포구    영등포동7가   32.7592     7
# 519296      서울특별시      영등포구    영등포동8가   92.6404    10
#
# [519297 rows x 13 columns]

# %%
dfLM
# Out:
#           기준년월   품목대분류명   품목중분류명      매출금액
# 0       201903       의류     여성의류   78.2521
# 1       201903  e상품/서비스   o2o서비스   96.3789
# 2       201903    출산/육아  육아용품서비스   92.4309
# 3       201903  e상품/서비스  e머니/상품권  108.9360
# 4       201903       생활     생활용품  165.6740
# ...        ...      ...      ...       ...
# 519292  202103   여가/스포츠       여행  141.1368
# 519293  202103  e상품/서비스   o2o서비스  138.6040
# 519294  202103     패션잡화   시계/주얼리   39.0818
# 519295  202103       식품     가공식품   32.7592
# 519296  202103  e상품/서비스   o2o서비스   92.6404
#
# [519297 rows x 4 columns]

# %%
df_e = dfLM[dfLM['품목대분류명'] == 'e상품/서비스']
grouped_e = pd.DataFrame(df_e['매출금액'].groupby(df_e['기준년월']).sum())
grouped_e
# Out:
#                 매출금액
# 기준년월
# 201903  7.020302e+06
# 201909  7.255877e+06
# 202003  9.464159e+06
# 202009  1.003509e+07
# 202103  1.164213e+07

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(grouped_e, 'ko--')
ax.set_xticks([201903, 201909, 202003, 202009, 202103])
# Out:
# [<matplotlib.axis.XTick at 0x20a9dd42ac0>,
#  <matplotlib.axis.XTick at 0x20a9dd65070>,
#  <matplotlib.axis.XTick at 0x20a9dd61880>,
#  <matplotlib.axis.XTick at 0x20a9dd8a910>,
#  <matplotlib.axis.XTick at 0x20a9dd8ae20>]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_e.drop('품목중분류명', axis=1, inplace=True)
df_e
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           기준년월   품목대분류명      매출금액
# 1       201903  e상품/서비스   96.3789
# 3       201903  e상품/서비스  108.9360
# 16      201903  e상품/서비스  100.6313
# 23      201903  e상품/서비스  153.1532
# 24      201903  e상품/서비스  156.2958
# ...        ...      ...       ...
# 519280  202103  e상품/서비스   55.3418
# 519281  202103  e상품/서비스   72.0728
# 519287  202103  e상품/서비스   38.5208
# 519293  202103  e상품/서비스  138.6040
# 519296  202103  e상품/서비스   92.6404
#
# [76052 rows x 3 columns]

# %%
#box plot
sns.factorplot( x = '기준년월', y = '매출금액', kind = 'box', data = df_e)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df_e = dfLM[dfLM['품목대분류명'] == 'e상품/서비스']

# %%
#e상품/서비스 월별 통계량
grouped = df_e['매출금액'].groupby(df_e['기준년월'])
grouped.describe()
# Out:
#           count        mean          std     min        25%       50%  \
# 기준년월
# 201903  10102.0  694.941756  1517.698939  2.5014  80.282975  215.5677
# 201909  16055.0  451.938766  1146.073742  0.4118  34.342800  105.9747
# 202003  18997.0  498.192318  1387.555583  0.1490  28.303900   95.4308
# 202009  12354.0  812.294634  1802.958051  0.9819  79.652775  246.7476
# 202103  18544.0  627.810893  1566.106174  0.5144  39.508125  133.7423
#
#                75%         max
# 기준년월
# 201903  642.029950  40478.2343
# 201909  361.230500  31477.3250
# 202003  353.734300  30735.7911
# 202009  772.869400  59184.8842
# 202103  493.887975  36004.5831

# %%
grouped = df_e['매출금액'].groupby(df_e['품모'])
grouped.describe()
# Out:
#            count        mean          std    min        25%        50%  \
# 품목중분류명
# e머니/상품권  21943.0  288.846074   907.006628  0.149  31.862050   99.40560
# o2o서비스   42064.0  914.417715  1822.649257  2.010  96.863275  285.14945
# 모바일상품    12045.0   51.086335    78.889615  0.150  13.922400   28.53290
#
#                75%         max
# 품목중분류명
# e머니/상품권  289.25340  59184.8842
# o2o서비스   900.85925  36004.5831
# 모바일상품     59.61200   2544.2227

# %%
df_e_1903 = df_e[df_e['기준년월'] == 201903]
df_e_1903
# Out:
#          기준년월   품목대분류명   품목중분류명       매출금액
# 1      201903  e상품/서비스   o2o서비스    96.3789
# 3      201903  e상품/서비스  e머니/상품권   108.9360
# 16     201903  e상품/서비스    모바일상품   100.6313
# 23     201903  e상품/서비스   o2o서비스   153.1532
# 24     201903  e상품/서비스    모바일상품   156.2958
# ...       ...      ...      ...        ...
# 68855  201903  e상품/서비스   o2o서비스   146.8155
# 68857  201903  e상품/서비스   o2o서비스    68.4341
# 68862  201903  e상품/서비스   o2o서비스   159.4851
# 68863  201903  e상품/서비스   o2o서비스   172.9989
# 68884  201903  e상품/서비스   o2o서비스  1327.6210
#
# [10102 rows x 4 columns]

# %%
#box plot
sns.factorplot( x = '기준년월', y = '매출금액', kind = 'box', data = df_e_1903)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df_e
# Out:
#           기준년월   품목대분류명   품목중분류명      매출금액
# 1       201903  e상품/서비스   o2o서비스   96.3789
# 3       201903  e상품/서비스  e머니/상품권  108.9360
# 16      201903  e상품/서비스    모바일상품  100.6313
# 23      201903  e상품/서비스   o2o서비스  153.1532
# 24      201903  e상품/서비스    모바일상품  156.2958
# ...        ...      ...      ...       ...
# 519280  202103  e상품/서비스   o2o서비스   55.3418
# 519281  202103  e상품/서비스   o2o서비스   72.0728
# 519287  202103  e상품/서비스   o2o서비스   38.5208
# 519293  202103  e상품/서비스   o2o서비스  138.6040
# 519296  202103  e상품/서비스   o2o서비스   92.6404
#
# [76052 rows x 4 columns]

# %%
df_e_1903_o2o = df_e_1903[df_e_1903['품목중분류명'] == 'o2o서비스']
df_e_1903_o2o
# Out:
#          기준년월   품목대분류명  품목중분류명       매출금액
# 1      201903  e상품/서비스  o2o서비스    96.3789
# 23     201903  e상품/서비스  o2o서비스   153.1532
# 26     201903  e상품/서비스  o2o서비스   336.6134
# 29     201903  e상품/서비스  o2o서비스   915.1530
# 30     201903  e상품/서비스  o2o서비스   738.5550
# ...       ...      ...     ...        ...
# 68855  201903  e상품/서비스  o2o서비스   146.8155
# 68857  201903  e상품/서비스  o2o서비스    68.4341
# 68862  201903  e상품/서비스  o2o서비스   159.4851
# 68863  201903  e상품/서비스  o2o서비스   172.9989
# 68884  201903  e상품/서비스  o2o서비스  1327.6210
#
# [6044 rows x 4 columns]

# %%
df_e_1903_o2o.describe()
# Out:
#            기준년월          매출금액
# count    6044.0   6044.000000
# mean   201903.0   1002.846624
# std         0.0   1764.683178
# min    201903.0     14.674900
# 25%    201903.0    166.713100
# 50%    201903.0    399.013300
# 75%    201903.0   1046.228800
# max    201903.0  25963.851200

# %%
#box plot
sns.factorplot( x = '품목중분류명', y = '매출금액', kind = 'box', data = df_e_1903_o2o)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
